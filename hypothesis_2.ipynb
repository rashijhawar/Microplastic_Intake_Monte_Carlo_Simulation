# %%
from hypothesis_2 import *

# %%
sim_df, food_df = run_monte_carlo_simulation('Data/Food_Microplastic_Intake_Data.xlsx')

# %%
plot_violin(sim_df, True, 10)
# Out:
# <Axes: title={'center': 'Monte Carlo Simulation: MP Intake by Diet Type for Top 10 Countries'}, xlabel='Country', ylabel='Simulated MP Intake (mg/day)'>

# %%
 plot_violin(sim_df, False, 10)
# Out:
# <Axes: title={'center': 'Monte Carlo Simulation: MP Intake by Diet Type for Bottom 10 Countries'}, xlabel='Country', ylabel='Simulated MP Intake (mg/day)'>

# %%
plot_stacked_bar(food_df, True, 10)
# Out:
# <Axes: title={'center': 'Contribution of Food Items to MP Intake (Top 10 Countries)'}, xlabel='Country', ylabel='Simulated MP Intake (mg/day)'>

# %%
plot_stacked_bar(food_df, False, 10)
# Out:
# <Axes: title={'center': 'Contribution of Food Items to MP Intake (Bottom 10 Countries)'}, xlabel='Country', ylabel='Simulated MP Intake (mg/day)'>
